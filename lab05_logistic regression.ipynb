# %%
import tensorflow as tf
x_train = [[1., 2.], [2., 3.], [3., 1.], [4., 3.], [5., 3.], [6., 2.]]
y_train = [[0.], [0.], [0.], [1.], [1.], [1.]]
x_test = [[5., 2.]]
y_test = [1.]

# %%
dataset = tf.data.Dataset.from_tensor_slices((x_train, y_train)).batch(len(x_train))

# %%
for e in dataset:
    print(e)
# Out:
# (<tf.Tensor: shape=(6, 2), dtype=float32, numpy=
# array([[1., 2.],
#        [2., 3.],
#        [3., 1.],
#        [4., 3.],
#        [5., 3.],
#        [6., 2.]], dtype=float32)>, <tf.Tensor: shape=(6, 1), dtype=float32, numpy=
# array([[0.],
#        [0.],
#        [0.],
#        [1.],
#        [1.],
#        [1.]], dtype=float32)>)

# %%
W = tf.Variable([[2.],[1.]])#, name = 'weight')
b = tf.Variable([0.,0.])#, name = 'bias')

# %%
def logistic_regression (features) : 
    hypothesis = tf.sigmoid(tf.matmul(features, W) + b)
    return hypothesis

# %%
def loss_fn (hypothesis, labels):
    cost = -tf.reduce_mean(labels * tf.math.log(hypothesis) + (1-labels) * tf.math.log(1- hypothesis))
    return cost

# %%
def grad(hypothesis, features, labels):
    with tf.GradientTape() as tape:
        loss_value = loss_fn(hypothesis, labels)
    return tape.gradient(loss_value, [W,b])

# %%
optimizer = tf.optimizers.SGD(learning_rate = 0.01)
EPOCHS = 100
for step in range(EPOCHS):
    for features, labels in iter(dataset):
        print('feature is', features)
        hypothesis = logistic_regression(features)
        grads = grad(hypothesis, features, labels)
        optimizer.apply_gradients(grads_and_vars = zip(grads, [W,b]))
        if step % 100 == 0:
            print('Iter: {}, Loss : {:.4f}'.format(step, loss_fn(features, labels)))
# Out:
# feature is tf.Tensor(
# [[1. 2.]
#  [2. 3.]
#  [3. 1.]
#  [4. 3.]
#  [5. 3.]
#  [6. 2.]], shape=(6, 2), dtype=float32)
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-434cd636c609> in <module>
#       6         hypothesis = logistic_regression(features)
#       7         grads = grad(hypothesis, features, labels)
# ----> 8         optimizer.apply_gradients(grads_and_vars = zip(grads, [W,b]))
#       9         if step % 100 == 0:
#      10             print('Iter: {}, Loss : {:.4f}'.format(step, loss_fn(features, labels)))
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py in apply_gradients(self, grads_and_vars, name, experimental_aggregate_gradients)
#     511       ValueError: If none of the variables have gradients.
#     512     """
# --> 513     grads_and_vars = _filter_grads(grads_and_vars)
#     514     var_list = [v for (_, v) in grads_and_vars]
#     515
#
# ~\anaconda3\lib\site-packages\tensorflow\python\keras\optimizer_v2\optimizer_v2.py in _filter_grads(grads_and_vars)
#    1268   filtered = tuple(filtered)
#    1269   if not filtered:
# -> 1270     raise ValueError("No gradients provided for any variable: %s." %
#    1271                      ([v.name for _, v in grads_and_vars],))
#    1272   if vars_with_empty_grads:
#
# ValueError: No gradients provided for any variable: ['Variable:0', 'Variable:0'].
