# %%
import tensorflow as tf

# %%
tf.random.set_seed(6)

X = [1., 2., 3., 4.]
Y = [1., 3., 5., 7.]

W = tf.Variable(tf.random.normal([1], 0., 1.)) # shape, 평균, 표준편차

# %%
for step in range(300):
    hypothesis = W*X
    cost = tf.reduce_mean(tf.square(hypothesis - Y))
    
    alpha = 0.001
    gradient = tf.reduce_mean(tf.multiply(tf.multiply(W, X) - Y, X))
    descent = W - tf.multiply(alpha, gradient)
    W.assign (descent)
    
    if step % 10 == 0:
        print('{:5} | {:10.4f} | {:10.6f}'.format(step, cost.numpy(), W.numpy()[0]))
# Out:
#     0 |     0.1667 |   1.666667
#    10 |     0.1667 |   1.666667
#    20 |     0.1667 |   1.666667
#    30 |     0.1667 |   1.666667
#    40 |     0.1667 |   1.666667
#    50 |     0.1667 |   1.666667
#    60 |     0.1667 |   1.666667
#    70 |     0.1667 |   1.666667
#    80 |     0.1667 |   1.666667
#    90 |     0.1667 |   1.666667
#   100 |     0.1667 |   1.666667
#   110 |     0.1667 |   1.666667
#   120 |     0.1667 |   1.666667
#   130 |     0.1667 |   1.666667
#   140 |     0.1667 |   1.666667
#   150 |     0.1667 |   1.666667
#   160 |     0.1667 |   1.666667
#   170 |     0.1667 |   1.666667
#   180 |     0.1667 |   1.666667
#   190 |     0.1667 |   1.666667
#   200 |     0.1667 |   1.666667
#   210 |     0.1667 |   1.666667
#   220 |     0.1667 |   1.666667
#   230 |     0.1667 |   1.666667
#   240 |     0.1667 |   1.666667
#   250 |     0.1667 |   1.666667
#   260 |     0.1667 |   1.666667
#   270 |     0.1667 |   1.666667
#   280 |     0.1667 |   1.666667
#   290 |     0.1667 |   1.666667
